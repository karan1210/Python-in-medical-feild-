# %%
# !pip install COVID19Py

# %%
import COVID19Py

# %%
covid19 = COVID19Py.COVID19()

# %%
covid19 = COVID19Py.COVID19(data_source='csbs')

# %%
latest = covid19.getLatest()
# OR LOCATIONS = covid19.getLocation()

# %%
# Expected one of: ['confirmed', 'deaths', 'recovered']

confirm = covid19.getLocations(rank_by='confirmed')

print(confirm)
# Out:
# [{'id': 0, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'New York', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.71455', 'longitude': '-74.00714'}, 'latest': {'confirmed': 182257, 'deaths': 19198, 'recovered': 0}}, {'id': 92, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'Illinois', 'county': 'Cook', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '41.84014932', 'longitude': '-87.81682325'}, 'latest': {'confirmed': 45223, 'deaths': 1922, 'recovered': 0}}, {'id': 1, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'Suffolk', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.87732808', 'longitude': '-72.85898036'}, 'latest': {'confirmed': 38252, 'deaths': 1296, 'recovered': 0}}, {'id': 2, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'prov
# ...

# %%
death = covid19.getLocations(rank_by='deaths')

print (death)
# Out:
# [{'id': 0, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'New York', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.71455', 'longitude': '-74.00714'}, 'latest': {'confirmed': 182257, 'deaths': 19198, 'recovered': 0}}, {'id': 92, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'Illinois', 'county': 'Cook', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '41.84014932', 'longitude': '-87.81682325'}, 'latest': {'confirmed': 45223, 'deaths': 1922, 'recovered': 0}}, {'id': 2, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'Nassau', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.74165225', 'longitude': '-73.58899619'}, 'latest': {'confirmed': 36965, 'deaths': 1818, 'recovered': 0}}, {'id': 60, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'prov
# ...

# %%
recover = covid19.getLocations(rank_by='recovered')

print (recover)
# Out:
# [{'id': 0, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'New York', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.71455', 'longitude': '-74.00714'}, 'latest': {'confirmed': 182257, 'deaths': 19198, 'recovered': 0}}, {'id': 1, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'Suffolk', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.87732808', 'longitude': '-72.85898036'}, 'latest': {'confirmed': 38252, 'deaths': 1296, 'recovered': 0}}, {'id': 2, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'Nassau', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.74165225', 'longitude': '-73.58899619'}, 'latest': {'confirmed': 36965, 'deaths': 1818, 'recovered': 0}}, {'id': 3, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'pro
# ...

# %%
us = covid19.getLocationByCountryCode("US")
print(us)
# Out:
# [{'id': 0, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'New York', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.71455', 'longitude': '-74.00714'}, 'latest': {'confirmed': 182257, 'deaths': 19198, 'recovered': 0}}, {'id': 1, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'Suffolk', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.87732808', 'longitude': '-72.85898036'}, 'latest': {'confirmed': 38252, 'deaths': 1296, 'recovered': 0}}, {'id': 2, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': 'New York', 'county': 'Nassau', 'last_updated': '2020-05-05T22:51:00Z', 'coordinates': {'latitude': '40.74165225', 'longitude': '-73.58899619'}, 'latest': {'confirmed': 36965, 'deaths': 1818, 'recovered': 0}}, {'id': 3, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'pro
# ...
